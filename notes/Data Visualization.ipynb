# %% [markdown]
# # Data Visualization

# %%
# Importing packages

library('gapminder')
library('ggrepel')
library('patchwork')
library('plotly')
library('tidyverse')
# Out:
# Loading required package: ggplot2
#
#
# Attaching package: ‘plotly’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     last_plot
#
#
# The following object is masked from ‘package:stats’:
#
#     filter
#
#
# The following object is masked from ‘package:graphics’:
#
#     layout
#
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
#
# ✔ tibble  2.1.3     ✔ purrr   0.3.2
# ✔ tidyr   0.8.3     ✔ dplyr   0.8.3
# ✔ readr   1.3.1     ✔ stringr 1.4.0
# ✔ tibble  2.1.3     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks plotly::filter(), stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
# Import data from csv stored in Github
pokemon = read_csv('https://raw.githubusercontent.com/the-tanvan/BIOS512/master/notes/data/pokemon.csv')
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Name = col_character(),
#   Type_1 = col_character(),
#   Type_2 = col_character(),
#   isLegendary = col_logical(),
#   Color = col_character(),
#   hasGender = col_logical(),
#   Egg_Group_1 = col_character(),
#   Egg_Group_2 = col_character(),
#   hasMegaEvolution = col_logical(),
#   Body_Style = col_character()
# )
#
# See spec(...) for full column specifications.

# %% [markdown]
# Documentation of Pokemon dataset: [Here](https://www.kaggle.com/alopez247/pokemon)

# %%
# Preview data with head function, argument specifies how many entries to show
pokemon %>% head(5)
# Out:
#   Number Name       Type_1 Type_2 Total HP Attack Defense Sp_Atk Sp_Def ⋯ Color
# 1 1      Bulbasaur  Grass  Poison 318   45 49     49       65     65    ⋯ Green
# 2 2      Ivysaur    Grass  Poison 405   60 62     63       80     80    ⋯ Green
# 3 3      Venusaur   Grass  Poison 525   80 82     83      100    100    ⋯ Green
# 4 4      Charmander Fire   NA     309   39 52     43       60     50    ⋯ Red
# 5 5      Charmeleon Fire   NA     405   58 64     58       80     65    ⋯ Red
#   hasGender Pr_Male Egg_Group_1 Egg_Group_2 hasMegaEvolution Height_m Weight_kg
# 1 TRUE      0.875   Monster     Grass       FALSE            0.71       6.9
# 2 TRUE      0.875   Monster     Grass       FALSE            0.99      13.0
# 3 TRUE      0.875   Monster     Grass        TRUE            2.01     100.0
# 4 TRUE      0.875   Monster     Dragon      FALSE            0.61       8.5
# 5 TRUE      0.875   Monster     Dragon      FALSE            1.09      19.0
#   Catch_Rate Body_Style
# ...

# %%
# Define dimensions of image
options(repr.plot.width=10, repr.plot.height=6)

# Example of a scatterplot
# Create ggplot object, set up x and y variables and the colorby
p = ggplot(pokemon,aes(x=Weight_kg, y=Height_m, color=isLegendary))
p = p + geom_point()
p

# Note R is case-sensitive
# Out:
# plot without title
